# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
history = msft.history(period="max")

history
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054485    0.062498    0.054485    0.059827
# 1986-03-14 00:00:00-05:00    0.059827    0.063032    0.059827    0.061963
# 1986-03-17 00:00:00-05:00    0.061963    0.063566    0.061963    0.063032
# 1986-03-18 00:00:00-05:00    0.063032    0.063566    0.060895    0.061429
# 1986-03-19 00:00:00-05:00    0.061429    0.061963    0.059827    0.060361
# ...                               ...         ...         ...         ...
# 2025-01-03 00:00:00-05:00  421.079987  424.029999  419.540009  423.350006
# 2025-01-06 00:00:00-05:00  428.000000  434.320007  425.480011  427.850006
# 2025-01-07 00:00:00-05:00  429.000000  430.649994  420.799988  422.369995
# 2025-01-08 00:00:00-05:00  423.459991  426.970001  421.540009  424.559998
# 2025-01-10 00:00:00-05:00  424.630005  424.709991  415.019989  418.950012
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
msft.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2023-11-15 00:00:00-05:00       0.75           0.0
# 2024-02-14 00:00:00-05:00       0.75           0.0
# 2024-05-15 00:00:00-04:00       0.75           0.0
# 2024-08-15 00:00:00-04:00       0.75           0.0
# 2024-11-21 00:00:00-05:00       0.83           0.0
#
# [93 rows x 2 columns]

# %%
msft.splits
# Out:
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64

# %%
msft.dividends
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2023-11-15 00:00:00-05:00    0.75
# 2024-02-14 00:00:00-05:00    0.75
# 2024-05-15 00:00:00-04:00    0.75
# 2024-08-15 00:00:00-04:00    0.75
# 2024-11-21 00:00:00-05:00    0.83
# Name: Dividends, Length: 84, dtype: float64

# %%
print(msft.financials)
print(msft.quarterly_financials)
# Out:
#                                                         2024-06-30  \
# Tax Effect Of Unusual Items                            -99918000.0
# Tax Rate For Calcs                                           0.182
# Normalized EBITDA                                   133558000000.0
# Total Unusual Items                                   -549000000.0
# Total Unusual Items Excluding Goodwill                -549000000.0
# Net Income From Continuing Operation Net Minori...   88136000000.0
# Reconciled Depreciation                              22287000000.0
# Reconciled Cost Of Revenue                           74114000000.0
# EBITDA                                              133009000000.0
# EBIT                                                110722000000.0
# Net Interest Income                                    222000000.0
# Interest Expense                                      2935000000.0
# Interest Income                                       3157000000.0
# ...

# %%
msft.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00056
# institutionsPercentHeld          0.73564
# institutionsFloatPercentHeld     0.73605
# institutionsCount             6961.00000

# %%
msft.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0879  653247546
# 1    2023-06-30                     Blackrock Inc.   0.0722  536245027
# 2    2023-06-30           State Street Corporation   0.0395  293614078
# 3    2023-06-30                           FMR, LLC   0.0283  210111250
# 4    2023-06-30      Price (T.Rowe) Associates Inc   0.0215  159904219
# 5    2023-06-30      Geode Capital Management, LLC   0.0199  148129470
# 6    2023-06-30                     Morgan Stanley   0.0166  123498322
# 7    2023-06-30          JP Morgan Chase & Company   0.0152  113024837
# 8    2022-12-31  Norges Bank Investment Management   0.0116   86316926
# 9    2023-06-30            Capital World Investors   0.0115   85507261
#
#           Value
# 0  222456919314
# 1  182612881494
# 2   99987338122
# 3   71551285075
# 4   54453782738
# 5   50444009713
# 6   42056118573
# 7   38489477991
# 8   20700525193
# ...

# %%
print(msft.balance_sheet)
print(msft.quarterly_balance_sheet)
# Out:
#                                                       2024-06-30  \
# Ordinary Shares Number                              7434000000.0
# Share Issued                                        7434000000.0
# Net Debt                                           33315000000.0
# Total Debt                                         67127000000.0
# Tangible Book Value                               121660000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   75531000000.0
# Other Short Term Investments                       57216000000.0
# Cash And Cash Equivalents                          18315000000.0
# Cash Equivalents                                    6744000000.0
# Cash Financial                                     11571000000.0
#
#                                                       2023-06-30  \
# Ordinary Shares Number                              7432000000.0
# ...

# %%
df = msft.balance_sheet

# %%
df
# Out:
#                                                       2024-06-30  \
# Ordinary Shares Number                              7434000000.0
# Share Issued                                        7434000000.0
# Net Debt                                           33315000000.0
# Total Debt                                         67127000000.0
# Tangible Book Value                               121660000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   75531000000.0
# Other Short Term Investments                       57216000000.0
# Cash And Cash Equivalents                          18315000000.0
# Cash Equivalents                                    6744000000.0
# Cash Financial                                     11571000000.0
#
#                                                       2023-06-30  \
# Ordinary Shares Number                              7432000000.0
# ...

# %%
df.index
# Out:
# Index(['Ordinary Shares Number', 'Share Issued', 'Net Debt', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Working Capital',
#        'Net Tangible Assets', 'Capital Lease Obligations',
#        'Common Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Retained Earnings', 'Capital Stock',
#        'Common Stock', 'Total Liabilities Net Minority Interest',
#        'Total Non Current Liabilities Net Minority Interest',
#        'Other Non Current Liabilities', 'Tradeand Other Payables Non Current',
#        'Non Current Deferred Liabilities', 'Non Current Deferred Revenue',
#        'Non Current Deferred Taxes Liabilities',
#        'Long Term Debt And Capital Lease Obligation',
#        'Long Term Capital Lease Obligation', 'Long Term Debt',
#        'Current Liabilities', 'Other Current Liabilities',
# ...

# %%
TotalDebt = df.loc['Total Debt']

# %%
TotalDebt
# Out:
# 2024-06-30    67127000000.0
# 2023-06-30    59965000000.0
# 2022-06-30    61270000000.0
# 2021-06-30    67775000000.0
# Name: Total Debt, dtype: object

# %%
print(msft.cash_flow)
print(msft.quarterly_cash_flow)
# Out:
#                                                     2024-06-30     2023-06-30  \
# Free Cash Flow                                   74071000000.0  59475000000.0
# Repurchase Of Capital Stock                     -17254000000.0 -22245000000.0
# Repayment Of Debt                               -29070000000.0  -2750000000.0
# Issuance Of Debt                                 29645000000.0            0.0
# Issuance Of Capital Stock                         2002000000.0   1866000000.0
# Capital Expenditure                             -44477000000.0 -28107000000.0
# End Cash Position                                18315000000.0  34704000000.0
# Beginning Cash Position                          34704000000.0  13931000000.0
# Effect Of Exchange Rate Changes                   -210000000.0   -194000000.0
# Changes In Cash                                 -16179000000.0  20967000000.0
# Financing Cash Flow                             -37757000000.0 -43935000000.0
# ...

# %%
print(msft.income_stmt)
print(msft.quarterly_income_stmt)
# Out:
#                                                         2024-06-30  \
# Tax Effect Of Unusual Items                            -99918000.0
# Tax Rate For Calcs                                           0.182
# Normalized EBITDA                                   133558000000.0
# Total Unusual Items                                   -549000000.0
# Total Unusual Items Excluding Goodwill                -549000000.0
# Net Income From Continuing Operation Net Minori...   88136000000.0
# Reconciled Depreciation                              22287000000.0
# Reconciled Cost Of Revenue                           74114000000.0
# EBITDA                                              133009000000.0
# EBIT                                                110722000000.0
# Net Interest Income                                    222000000.0
# Interest Expense                                      2935000000.0
# Interest Income                                       3157000000.0
# ...

# %%
msft.sustainability
# Out:
#                                                                            esgScores
# maxAge                                                                         86400
# totalEsg                                                                       14.23
# environmentScore                                                                1.65
# socialScore                                                                     7.62
# governanceScore                                                                 4.96
# ratingYear                                                                      2025
# ratingMonth                                                                        1
# highestControversy                                                               3.0
# peerCount                                                                        604
# esgPerformance                                                              LAG_PERF
# ...

# %%
msft.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         14   38     5     0           0
# 1    -1m         14   38     5     0           0
# 2    -2m         14   38     5     0           0
# 3    -3m         14   38     5     0           0

# %%
msft.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 3, 13),
#  'Ex-Dividend Date': datetime.date(2025, 2, 20),
#  'Earnings Date': [datetime.date(2025, 1, 29)],
#  'Earnings High': 3.47,
#  'Earnings Low': 3.02,
#  'Earnings Average': 3.13371,
#  'Revenue High': 70520000000,
#  'Revenue Low': 68261000000,
#  'Revenue Average': 68861379010}

# %%
msft.news
# Out:
# [{'id': 'c2181653-4239-35f0-9ddb-8d29c833be97',
#   'content': {'id': 'c2181653-4239-35f0-9ddb-8d29c833be97',
#    'contentType': 'STORY',
#    'title': "Nvidia's AI empire: A look at its top startup investments",
#    'description': '',
#    'summary': 'No company has capitalized on the AI revolution more dramatically than Nvidia. Its revenue, profitability, and cash reserves have skyrocketed since the introduction of ChatGPT a little over two years ago — and the many competitive generative AI services that have launched since. And its stock price soared more than eightfold. During that period, the world’s leading high-performance GPU maker has used its ballooning fortunes to significantly increase investments in all sorts of startups but parti',
#    'pubDate': '2025-01-13T03:39:17Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'TechCrunch', 'url': 'https://techcrunch.com/'},
# ...

# %%
df = msft.analyst_price_targets

# %%
df
# Out:
# {'current': 418.95,
#  'low': 420.0,
#  'high': 650.0,
#  'mean': 508.4636,
#  'median': 500.0}

# %%
df['current']
# Out:
# 418.95

# %%
import os
from getpass import getpass
import openai

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or getpass(
    "Enter OpenAI API Key: "
)

# %%
openai_model = "gpt-4o-mini"

# %%
from langchain_openai import ChatOpenAI

# For normal accurate responses
llm = ChatOpenAI(temperature=0.0, model=openai_model, openai_api_key = os.environ["OPENAI_API_KEY"])

# %%
from typing_extensions import TypedDict

class State(TypedDict):
    graph_state: str
    graph_ticker: str

# %%
def node_1(state):
    print("---Node 1---")
    return {"graph_state": state['graph_state']}

def node_2(state):
    print("---Analyst Valuation---")
    ticker = yf.Ticker(state['graph_ticker'])
    df = ticker.analyst_price_targets
    current = df['current']
    return {"graph_state": current}

def node_3(state):
    print("---Sustainability---")
    ticker = yf.Ticker(state['graph_ticker'])
    df = ticker.sustainability
    
    response = llm(f"""using this data frame {df} tell me if this company is a ethically 
                    sustainable company, I would also like you to format it as 
                    # ?/10 for topic, this is due to...""")

    return {"graph_state": response.content}

def node_4(state):
    print("---Profitability---")
    ticker = yf.Ticker(state['graph_ticker'])
    df = ticker.financials
    
    response = llm(f"""using this data frame {df} tell me if this company is a 
                    profitable company, I would also like you to format it as 
                    # ?/10 for topic, this is due to...""")

    return {"graph_state": response.content}

# %%
from typing import Literal

def decide_mood(state) -> Literal["node_2", "node_3", "node_4"]:
    
    # Often, we will use state to decide on the next node to visit
    user_input = state['graph_state'] 
    print(user_input)
    # Here, let's just do a 50 / 50 split between nodes 2, 3
    if user_input == "profit":

        # 50% of the time, we return Node 2
        return "node_4"
    
    if user_input == "price":

        # 50% of the time, we return Node 4
        return "node_2"
    
    if user_input == "sustain":
    # 50% of the time, we return Node 3
        return "node_3"

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END

# %%
# Build graph
builder = StateGraph(State)

builder.add_node("node_1", node_1)
builder.add_node("node_2", node_2)
builder.add_node("node_3", node_3)
builder.add_node("node_4", node_4)

# Logic
builder.add_edge(START, "node_1")
builder.add_conditional_edges("node_1", decide_mood)
builder.add_edge("node_2", END)
builder.add_edge("node_3", END)
builder.add_edge("node_4", END)

# Add
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# { sustain - profit - price } - graph_state variables

# %%
result = graph.invoke({"graph_state": "profit", "graph_ticker": "MSFT"})
# Out:
# ---Node 1---
# profit
# ---Profitability---
# C:\Users\Joshu\AppData\Local\Temp\ipykernel_19980\4002034012.py:28: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm(f"""using this data frame {df} tell me if this company is a

# %%
text = result['graph_state']

formatted_text = text.replace("\n", "\n---\n")

print(formatted_text)
# Out:
# To determine if the company is profitable, we can analyze key financial metrics from the provided data. Here are some important indicators of profitability:
# ---
#
# ---
# 1. **Net Income**: This is the profit after all expenses, taxes, and costs have been deducted from total revenue. The net income for the most recent year (2024-06-30) is **$88,136,000,000**, which is a positive figure, indicating profitability.
# ---
#
# ---
# 2. **EBITDA**: Earnings Before Interest, Taxes, Depreciation, and Amortization is another measure of profitability. The EBITDA for 2024 is **$133,009,000,000**, which is also positive.
# ---
#
# ---
# 3. **EPS (Earnings Per Share)**: The diluted EPS for 2024 is **$11.8**, which indicates that the company is generating earnings for its shareholders.
# ---
#
# ---
# ...

# %% [markdown]
# ## Super Agent

# %%
from typing_extensions import TypedDict

class State(TypedDict):
    response: str
    final_answer: str
    question: str
    ticker: str
    next_action: str
    history: str

# %%
def assistant_node(state):
    print("---   Assistant Node   ---")
    tools = """"Stock_Price_Value_Node", "Sustainability_Node", "Financials_Node", "Finalise_Node", "Cashflow_Node"""""
    response = llm(f"""Based on the question, do you believe this can be answered using 
                   the current content, 
                   if this is the case, please reply
                   with "Finalise_Node", otherwise, think based on what tools we have available
                   could help you find the correct answer, and answer as the name of the 
                   tool, here is the list of tools {tools}, here is the question 
                   {state['question']} here is the response so far 
                   {state['final_answer']}, if you have used all the tools in the
                   history, enter the "Finalise_Node" here is the history {state['history']}""")
    print(response.content)
    return {"response": response.content, "history": state['history'] + "    " + response.content}

# %%
def Valuation(state):
    print("---Analyst Valuation---")
    ticker = yf.Ticker(state['ticker'])
    df = ticker.analyst_price_targets
    answer = df.values
    response = llm(f"""This is the table of contents: {df}, Summarise the table of contents, make sure we do not get rid of any details that might help with answering questions on this text.""")
    return {"final_answer": df, "history": state['history'] + response.content}

def Sustainability(state):
    print("---Sustainability---")
    ticker = yf.Ticker(state['ticker'])
    df = ticker.sustainability
    response = llm(f"""This is the table of contents: {df}, Summarise the table of contents, make sure we do not get rid of any details that might help with answering questions on this text.""")

    answer = df.values

    return {"final_answer": df, "history": state['history'] + response.content}

def Financials(state):
    print("---Financials---")
    ticker = yf.Ticker(state['ticker'])
    df = ticker.financials
    answer = df.values
    response = llm(f"""This is the table of contents: {df}, Summarise the table of contents, make sure we do not get rid of any details that might help with answering questions on this text.""")

    return {"final_answer": df, "history": state['history'] + response.content}

def Cashflow(state):
    print("---Cashflow---")
    ticker = yf.Ticker(state['ticker'])
    df = ticker.cash_flow

    answer = df.values
    response = llm(f"""This is the table of contents: {df}, Summarise the table of contents, make sure we do not get rid of any details that might help with answering questions on this text.""")

    return {"final_answer": df, "history": state['history'] + response.content}

def Finalise(state):
    print("---Final---")
    print(state['final_answer'])
    response = llm(f"""using the current context {state['final_answer']} try to 
                   answer the question {state['question']}, do not lie.""")
    print(state['history'])

    return {"final_answer": response, "history": state['history'] + response.content}

# %%
from typing import Literal

def decide_node(state) -> Literal["Stock_Price_Value_Node", "Sustainability_Node", "Financials_Node", "Finalise_Node", "Cashflow_Node"]:
    print("Deciding")
    # Often, we will use state to decide on the next node to visit
    response_input = state['response'] 
    print(response_input)
    # Here, let's just do a 50 / 50 split between nodes 2, 3
    return response_input

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END

# %%
# Build graph
builder = StateGraph(State)

builder.add_node("Assistant_Node", assistant_node)
builder.add_node("Stock_Price_Value_Node", Valuation)
builder.add_node("Sustainability_Node", Sustainability)
builder.add_node("Financials_Node", Financials)
builder.add_node("Finalise_Node", Finalise)
builder.add_node("Cashflow_Node", Cashflow)

# Logic
builder.add_edge(START, "Assistant_Node")
builder.add_conditional_edges("Assistant_Node", decide_node)
builder.add_edge("Cashflow_Node", "Assistant_Node")
builder.add_edge("Stock_Price_Value_Node", "Assistant_Node")
builder.add_edge("Sustainability_Node", "Assistant_Node")
builder.add_edge("Financials_Node", "Assistant_Node")
builder.add_edge("Finalise_Node", END)

# Add
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# **python

# %%
result = graph.invoke({"question": "what is the price difference between the current price of microsoft and the average of the brokers price target of microsoft", "ticker": "MSFT", "final_answer": "not completed", "history": "started"})
# Out:
# ---   Assistant Node   ---
# Stock_Price_Value_Node
# Deciding
# Stock_Price_Value_Node
# ---Analyst Valuation---
# ---   Assistant Node   ---
# Finalise_Node
# Deciding
# Finalise_Node
# ---Final---
# {'current': 418.95, 'low': 420.0, 'high': 650.0, 'mean': 508.4636, 'median': 500.0}
# started    Stock_Price_Value_NodeThe table of contents provides a summary of a dataset with the following key statistics:
#
# - **Current Value**: 418.95
# - **Lowest Value**: 420.0
# - **Highest Value**: 650.0
# - **Mean (Average)**: 508.4636
# - **Median (Middle Value)**: 500.0
#
# This information indicates that the current value is slightly below the lowest recorded value, while the mean and median suggest that the dataset has a central tendency around 500. The highest value is significantly above both the current and lowest values.    Finalise_Node

# %%
result
# Out:
# {'response': 'Finalise_Node',
# ...
